# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/spam.csv")  # ../ car notebooks est dans un sous-dossier
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.columns
# Out:
# Index(['Category', 'Message'], dtype='object')

# %%
df.shape
# Out:
# (5572, 2)

# %%
df.isnull().sum()
# Out:
# Category    0
# Message     0
# dtype: int64

# %%
df['Category'].value_counts()
sns.countplot(x='Category', data=df)
plt.show()

# %%
df['length'] = df['Message'].apply(len)
df.head()
# Out:
#   Category                                            Message  length
# 0      ham  Go until jurong point, crazy.. Available only ...     111
# 1      ham                      Ok lar... Joking wif u oni...      29
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 3      ham  U dun say so early hor... U c already then say...      49
# 4      ham  Nah I don't think he goes to usf, he lives aro...      61

# %%
sns.histplot(data=df, x='length', hue='Category', bins=50, alpha=0.7)
plt.show()

# %%
from collections import Counter
import re
all_words = ' '.join(df['Message']).lower()
all_words = re.findall(r'\b\w+\b', all_words)

word_counts = Counter(all_words)
print(word_counts.most_common(20))
# Out:
# [('i', 3021), ('to', 2250), ('you', 2245), ('a', 1450), ('the', 1336), ('u', 1203), ('and', 980), ('in', 901), ('is', 896), ('me', 807), ('my', 766), ('it', 752), ('for', 711), ('your', 681), ('of', 623), ('call', 590), ('that', 586), ('s', 578), ('have', 575), ('on', 538)]
